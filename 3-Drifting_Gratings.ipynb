# %% [markdown]
# # Drifting-gratings analysis
#
# Contact: laquitainesteeve@gmail.com (based on Guilhelm's guilhelm-dev branch)
#
# Description: For every cell, computes its response to a drifting-gratings stimulus — 8 directions (45° apart), each repeated 4 times — as per-direction rasters, a PSTH, and a polar **direction-tuning** curve with a direction-selectivity index. Spikes are split per direction using the recording's vec file (the same engine as the Standard Vec analysis).
#
# **Requirements**
# - Run the preprocessing notebook first (you need the triggers and the sorted-neurons `.pkl` files).
# - A vec file describing the stimulus, in `<root>/ResourcesAndTools/StandardVec`.
# - Configure your experiment in `./params.py`.
#
# **Execution time**: < 1 min.
#
# Tested on Ubuntu 24.04.1 LTS (32 cores, 188 GB RAM, Intel(R) Core(TM) i9-14900K @ 3.2/5.8 GHz).

# %% [markdown]
# ## Setup
#
# 1. Create, activate (env/..yml) and setup the virtual environment :
#
#     ```python
#     python -m ipykernel install --user --name standard_analysis_pipeline --display-name "standard_analysis_pipeline"
#     ```
#
# 2. Configure your experiment in ./params.py

# %%
# %load_ext autoreload
# %autoreload 2

# standard packages
import os
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# project packages
import params  # experiment parameters
import utils  # shared helpers
from utils import drifting_gratings as analysis  # this notebook's analysis functions

# %% [markdown]
# ## Load data
#
# - Values come from your `params.py` file; only change them by hand for a one-off run.
# - You will be asked to type the **recording number**, the **grating speed**, then the **vec file number**.
# - **Mandatory for every run.**

# %%
# %%time

# Asks for: recording number, grating speed, then vec file number.
# get_all_inputs also reads the number of repetitions from the vec and asks you to confirm it
(
    cells,
    spike_times,
    stim_onsets,
    vec_keys,
    seq_len,
    seq_sep,
    DG_directory,
    n_repetitions,
) = analysis.get_all_inputs_for_dg_analysis(params)

# %% [markdown]
# ## Compute rasters and direction tuning

# %% [markdown]
# - The stimulus is 8 gratings, each drifting at a different angle, shown at 50 Hz. Speed sets how long each grating sweeps (slow = 12 s). Each of the 8 directions is repeated 4 times.
# - For every cell, spikes are split per direction (via the vec file), then a direction-tuning curve is computed and saved to the DG analysis folder.
# - **Requirements**: "Load data" cell run.
# - **Execution time**: < 1 sec.

# %%
# %%time

# Compute per-direction rasters + tuning for every cell, saved to the DG analysis folder.
analysis.compute_dg_rasters(
    cells,
    spike_times,
    stim_onsets,
    vec_keys,
    seq_len,
    seq_sep,
    DG_directory,
    params,
    n_repetitions=n_repetitions,
)

# %% [markdown]
# ## Plot and save all figures
#
# - Saves one figure per cell (raster + PSTH + polar tuning) into `DG_directory/DG_figs`.
# - Set `show=True` to also display each figure in the notebook.
# - **Requirements**: "Compute" cell run.
# - **Execution time**: ~30 sec.

# %%
# %%time

# Create and save one figure per cell. Returns the last figure (shown below).
fig = analysis.plot_dg_rasters(DG_directory, seq_sep, seq_len, params)
fig

# %% [markdown]
# ## (Optional) How the direction-tuning metrics are computed
#
# `compute_tuning` (used above, per cell) just chains a few small metric functions. Here we
# run them one by one on an example cell's raster, so you can see what each number on the
# polar plots actually means.

# %%
# Load the saved DG data and take one responsive example cell.
DG_set = utils.load_obj(os.path.join(DG_directory, f"DG_data_exp{params.exp}"))
example_cell = max(
    DG_set, key=lambda c: DG_set[c]["Rtune"]
)  # the most direction-selective one
ch_raster = DG_set[example_cell][
    "rasters"
]  # per-repetition, per-direction spike raster

# The metric functions, called one at a time:
counts, maxcount, bins = analysis.compute_dg_psth(
    ch_raster, seq_sep, n_repeats=n_repetitions
)
tune = analysis.compute_direction_responses(
    counts, seq_len, seq_sep
)  # total response per direction
tune_norm, atune, R = analysis.compute_tuning_vector(
    tune
)  # preferred direction + strength
IDX = analysis.compute_dsi(tune_norm, atune)  # direction-selectivity index

print(f"Cell {example_cell}:")
print(f"  preferred direction  = {np.degrees(atune) % 360:.0f} deg")
print(f"  tuning strength R     = {R:.2f}")
print(f"  direction-sel. index  = {IDX:.2f}")

# %% [markdown]
# ## Access the data and make your own plots
#
# `compute_dg_rasters` saves `DG_set = {cell: data}`, where each `data` holds:
# - `Tuning` — per-direction response (9 values; the last repeats the first to close the polar curve)
# - `atune`, `Rtune` — preferred direction (radians) and tuning strength
# - `IDX` — direction-selectivity index
# - `rasters`, `counts`, `bins` — the raster rows and PSTH histogram
#
# Load it and plot whatever you like, **without opening `drifting_gratings.py`**.

# %%
# Load the saved tuning data and look at one cell.
DG_set = utils.load_obj(os.path.join(DG_directory, f"DG_data_exp{params.exp}"))
print(f"Cells with tuning data: {len(DG_set)}")

example_cell = list(DG_set.keys())[0]
data = DG_set[example_cell]
print(f"Fields per cell: {sorted(data.keys())}")
print(
    f"Cell {example_cell}: preferred angle = {data['atune']:.2f} rad, "
    f"R = {data['Rtune']:.2f}, IDX = {data['IDX']:.2f}"
)

# %%
# Roll your own plot from the saved data (no need to open drifting_gratings.py).
# Example: the polar direction-tuning curve for one cell.
cell_to_show = example_cell  # change to any cell id in DG_set
data = DG_set[cell_to_show]
fontsize = 16

theta = np.linspace(0, 2 * np.pi, len(data["Tuning"]))  # 8 directions + closing point

fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, polar=True)
ax.plot(theta, data["Tuning"], color="#B85A8F", lw=2.5)
ax.fill(theta, data["Tuning"], color="#B85A8F", alpha=0.2)
ax.plot(
    [data["atune"], data["atune"]], [0, data["Rtune"]], color="k", lw=2
)  # preferred direction
ax.set_thetagrids(range(0, 360, 45), fontsize=fontsize - 2)
ax.set_yticks([0.5, 1])
ax.set_yticklabels(["0.5", "1"], fontsize=fontsize - 4)
ax.set_title(f"Cell {cell_to_show} — direction tuning", fontsize=fontsize + 2, pad=20)
plt.show()
